# %%
def add():
    x=int(input("number1:"))
    y=int(input("number2:"))
    return x+y

print(add())
# Out:
# number1: 4
# number2: 5
# 9

# %%
def add1(x,y):
    print(x+y)
add1(55,67)
# Out:
# 122
