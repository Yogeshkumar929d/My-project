# %%
import random as rd
d=int(input("enter mobile number"))
if len(str(d))==10: 
    otp=rd.randint(11111,99999)
    print(otp)
    verify=int(input("enter your otp"))
    if verify==otp:
        print("number verified")
    else:
        print("not verified")
else:
    print("length must be 10 digit number")
# Out:
# enter mobile number 1234567891
# 98454
# enter your otp 98454
# number verified

# %%
pip install pywhatkit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pywhatkit as pwk
import random as rd
otp=rd.randint(1111,9999)
pwk.sendwhatmsg_instantly("+917023978814",f"{otp}",wait_time=1,tab_close=True,close_time=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 4
#       2 import random as rd
#       3 otp=rd.randint(1111,9999)
# ----> 4 pwk.sendwhatmsg_instantly("+917023978814",f"{otp}",wait_time=1,tab_close=True,close_time=5)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pywhatkit\whats.py:31, in sendwhatmsg_instantly(phone_no, message, wait_time, tab_close, close_time)
#      29 time.sleep(4)
#      30 pg.click(core.WIDTH / 2, core.HEIGHT / 2)
# ---> 31 time.sleep(wait_time - 4)
#      32 pg.press("enter")
#      33 log.log_message(_time=time.localtime(), receiver=phone_no, message=message)
#
# ValueError: sleep length must be non-negative

# %%
pwk.search("www.instagram.com")

# %%
pwk.playonyt("carryminati")
# Out:
# 'https://www.youtube.com/watch?v=BL3V_CsOSKQ\\\\u0026pp=YAHIAQHwAQG6AwIYAugFAaIGFQFfVp7joWLv9C-MssR534KwIg4FlJAHAtIHCQl3GAGHKiGM7w%3D%3D'

# %%
pip install customtkinter
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
#    ---------------------------------------- 0/2 [darkdetect]
#    -------------------- ------------------- 1/2 [customtkinter]
#    -------------------- ------------------- 1/2 [customtkinter]
#    -------------------- ------------------- 1/2 [customtkinter]
#    -------------------- ------------------- 1/2 [customtkinter]
#    -------------------- ------------------- 1/2 [customtkinter]
#    -------------------- ------------------- 1/2 [customtkinter]
#    -------------------- ------------------- 1/2 [customtkinter]
#    -------------------- ------------------- 1/2 [customtkinter]
#    -------------------- ------------------- 1/2 [customtkinter]
#    ---------------------------------------- 2/2 [customtkinter]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import customtkinter as ctk
ctk.set_appearance_mode("dark")
ctk.set_default_color_theme("blue")
app=ctk.CTk()
app.geometry("300x400")
app.title("my page")
label1 = ctk.CTkLabel(app,text="welcome at my app !").pack()
label2=ctk.CTkLabel(app,text="username").place(x=40,y=100)
label3=ctk.CTkLabel(app,text="password").place(x=40,y=140)
e1=ctk.CTkEntry(app).place(x=140,y=100)
e2=ctk.CTkEntry(app).place(x=140,y=140)
b1=ctk.CTkButton(app,text="login").place(x=120,y=200)
ctk.CTkButton(app,text="close",command=app.destroy).pack()
app.mainloop()

# %%
import mysql.connector as ms
conn=ms.connect(host="localhost",user="root",password="root",database='sbpgm')
mycursor=conn.cursor()

# %%
import customtkinter as ctk
from tkinter import messagebox
def signin():
            def check_login():
                username=e2.get()
                password=e3.get()
                try:
                    query=f"select * from userinfo where username='{username}' and password='{password}'"
                    mycursor.execute(query)
                    result=mycursor.fetchone()
        
                    if result:
                        # print("login successful")
                       messagebox.showinfo("success","your account has been login") 
                    else:
                        # print("invalid username or password")
                        messagebox.showerror("invalid","invalid credentiols")

                except Exception as e:
                    print(e)
                        
            ctk.set_appearance_mode("dark")
            ctk.set_default_color_theme("blue")
            app=ctk.CTk()
            app.geometry("300x400")
            app.title("webpage")
            label1 = ctk.CTkLabel(app,text="welcome at my page!").pack()
            label2=ctk.CTkLabel(app,text="name").place(x=40,y=100)
            label3=ctk.CTkLabel(app,text="username").place(x=40,y=140)
            label4=ctk.CTkLabel(app,text="password").place(x=40,y=180)
            e1=ctk.CTkEntry(app)
            e1.place(x=140,y=100)
            e2=ctk.CTkEntry(app)
            e2.place(x=140,y=140)
            e3=ctk.CTkEntry(app,show="*")
            e3.place(x=140,y=180)
            # b1=ctk.CTkButton(app,text="login").place(x=120,y=220)
            b2=ctk.CTkButton(app,text="signin",command=check_login).place(x=120,y=260)
            app.mainloop()

# %%
signin()

# %%
import customtkinter as ctk
from tkinter import messagebox
def signup():
    def create_account():
        value1=e2.get()
        value0=e3.get()
        value2=e4.get()
        if value0!=value2:
            # print("password does not match")
            messagebox.showwarning("warning","password did not match")
            return
        try:
            query=f"insert into userinfo values('{value1}','{value2}')"
            mycursor.execute(query)
            conn.commit()
        except Exception as e:
            print(e)
    ctk.set_appearance_mode("dark")
    ctk.set_default_color_theme("blue")
    app=ctk.CTk()
    app.geometry("300x400")
    app.title("webpage")
    label1 = ctk.CTkLabel(app,text="create your account").pack()
    label2=ctk.CTkLabel(app,text="name").place(x=40,y=100)
    label3=ctk.CTkLabel(app,text="username").place(x=40,y=140)
    label4=ctk.CTkLabel(app,text="password").place(x=40,y=180)
    label5=ctk.CTkLabel(app,text="cnfpassww").place(x=40,y=220)
    e1=ctk.CTkEntry(app)
    e1.place(x=140,y=100)
    e2=ctk.CTkEntry(app)
    e2.place(x=140,y=140)
    e3=ctk.CTkEntry(app,show="*")
    e3.place(x=140,y=180)
    e4=ctk.CTkEntry(app,show="*")
    e4.place(x=140,y=220)
    b1=ctk.CTkButton(app,text="signup",command=create_account).place(x=120,y=260)
    # b2=ctk.CTkButton(app,text="signin").place(x=120,y=300)
    app.mainloop()

# %%
signup()

# %%
import customtkinter as ctk
def mainpage():
            ctk.set_appearance_mode("dark")
            ctk.set_default_color_theme("blue")
            app=ctk.CTk()
            app.geometry("400x400")
            app.title("webpage")
            b1=ctk.CTkButton(app,text="signin",command=signin).place(x=50,y=100)
            b2=ctk.CTkButton(app,text="signup",command=signup).place(x=50,y=130)
            app.mainloop()

# %%
mainpage()
# Out:
# invalid username or password
# login successful
# login successful

# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
