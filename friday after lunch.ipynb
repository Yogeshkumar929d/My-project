# %%
x=5
try:
    print(x)
except:
    print("x ko toh define karo")
# Out:
# 5

# %%
try:
    print(5/5)
except:
    print("zero ki table me sirf zero aata hai")
else:
    print("try block code is working")
finally:
    print("code is completed")
# Out:
# 1.0
# try block code is working
# code is completed

# %%
try:
    print(1/0)
except Exception as e:
    print(e)
# Out:
# division by zero
